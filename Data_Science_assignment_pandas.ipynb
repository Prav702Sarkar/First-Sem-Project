# %% [markdown]
# <a href="https://colab.research.google.com/github/Prav702Sarkar/First-Sem-Project/blob/main/Data_Science_assignment_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Match Date": ["2023-06-15", "2022-11-10", "2021-06-13", "2018-07-10"],
    "England Goals": [1, 2, 0, 1],
    "France Goals": [1, 1, 2, 2],
    "Venue": ["Wembley", "Parc des Princes", "Stade de France", "Kazan Arena"]
}

df = pd.DataFrame(data)

csv_file_path = "/content/england_vs_france_matches.csv"
df.to_csv(csv_file_path, index=False)


csv_file_path
# Out:
# '/content/england_vs_france_matches.csv'

# %%
#find thr number of rows and columns
df.shape
# Out:
# (4, 4)

# %%
#how does a data looklike
df.sample(2)
# Out:
#    Match Date  England Goals  France Goals             Venue
# 1  2022-11-10              2             1  Parc des Princes
# 3  2018-07-10              1             2       Kazan Arena

# %%
df.head(3) #data from top
# Out:
#    Match Date  England Goals  France Goals             Venue
# 0  2023-06-15              1             1           Wembley
# 1  2022-11-10              2             1  Parc des Princes
# 2  2021-06-13              0             2   Stade de France

# %%
#find number of rows from bottom
df.tail(8)
# Out:
#    Match Date  England Goals  France Goals             Venue
# 0  2023-06-15              1             1           Wembley
# 1  2022-11-10              2             1  Parc des Princes
# 2  2021-06-13              0             2   Stade de France
# 3  2018-07-10              1             2       Kazan Arena

# %%
#find the info of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Match Date     4 non-null      object
#  1   England Goals  4 non-null      int64
#  2   France Goals   4 non-null      int64
#  3   Venue          4 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes

# %%
#how does the data looklike mathemathically
df.describe() #apply only on numerical columns
# Out:
#        England Goals  France Goals
# count       4.000000       4.00000
# mean        1.000000       1.50000
# std         0.816497       0.57735
# min         0.000000       1.00000
# 25%         0.750000       1.00000
# 50%         1.000000       1.50000
# 75%         1.250000       2.00000
# max         2.000000       2.00000

# %%
#how to find the null value
df.isnull()
# Out:
#    Match Date  England Goals  France Goals  Venue
# 0       False          False         False  False
# 1       False          False         False  False
# 2       False          False         False  False
# 3       False          False         False  False

# %%
df.isnull().sum()
# Out:
# Match Date       0
# England Goals    0
# France Goals     0
# Venue            0
# dtype: int64

# %%
#remove the null value
#df.dropna(inplace=True)
df.shape
# Out:
# (4, 4)

# %%
df.isnull().sum()
# Out:
# Match Date       0
# England Goals    0
# France Goals     0
# Venue            0
# dtype: int64

# %%
#how to find duplicate value
df.duplicated().sum()
# Out:
# 0

# %%
#indexing and slicing
df.columns
# Out:
# Index(['Match Date', 'England Goals', 'France Goals', 'Venue'], dtype='object')

# %%
df["Venue"]
# Out:
# 0             Wembley
# 1    Parc des Princes
# 2     Stade de France
# 3         Kazan Arena
# Name: Venue, dtype: object

# %%
df.loc[0:5,['Match Date', 'England Goals', 'France Goals', 'Venue']]
# Out:
#    Match Date  England Goals  France Goals             Venue
# 0  2023-06-15              1             1           Wembley
# 1  2022-11-10              2             1  Parc des Princes
# 2  2021-06-13              0             2   Stade de France
# 3  2018-07-10              1             2       Kazan Arena

# %%
df[4:4]
# Out:
# Empty DataFrame
# Columns: [Match Date, England Goals, France Goals, Venue]
# Index: []

# %%
#sort the value of column in ascending or descending
df.sort_values(by="Venue",ascending=False)
# Out:
#    Match Date  England Goals  France Goals             Venue
# 0  2023-06-15              1             1           Wembley
# 2  2021-06-13              0             2   Stade de France
# 1  2022-11-10              2             1  Parc des Princes
# 3  2018-07-10              1             2       Kazan Arena

# %%
df.sort_values(by="Venue",ascending=True)
# Out:
#    Match Date  England Goals  France Goals             Venue
# 3  2018-07-10              1             2       Kazan Arena
# 1  2022-11-10              2             1  Parc des Princes
# 2  2021-06-13              0             2   Stade de France
# 0  2023-06-15              1             1           Wembley

# %%
df.isnull().sum()
# Out:
# Match Date       0
# England Goals    0
# France Goals     0
# Venue            0
# dtype: int64

# %%
df.dropna(inplace=True) #how to drop the null value

# %%
df.isnull().sum()
# Out:
# Match Date       0
# England Goals    0
# France Goals     0
# Venue            0
# dtype: int64

# %%
#find the unique number value
df["Venue"].unique()
# Out:
# array(['Wembley', 'Parc des Princes', 'Stade de France', 'Kazan Arena'],
#       dtype=object)

# %%
#number of unique value
df["Venue"].nunique()
# Out:
# 4
